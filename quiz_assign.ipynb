# %% [markdown]
# # Q2

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('more-data-processing/datasets/census.csv')

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
frames = ['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014']
df[frames]
# Out:
#       POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0             4785161          4801108          4816089          4830533
# 1               54660            55253            55175            55038
# 2              183193           186659           190396           195126
# 3               27341            27226            27159            26973
# 4               22861            22733            22642            22512
# ...               ...              ...              ...              ...
# 3188            43593            44041            45104            45162
# 3189            21297            21482            21697            22347
# 3190            21102            20912            20989            21022
# 3191             8545             8469             8443             8443
# 3192             7181             7114             7065             7160
#
#       POPESTIMATE2014
# 0             4846411
# 1               55290
# ...

# %%
df['AVG'] = df[frames].apply(lambda z: np.mean(z),axis='columns')

# %%
df[frames+['AVG']]
# Out:
#       POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0             4785161          4801108          4816089          4830533
# 1               54660            55253            55175            55038
# 2              183193           186659           190396           195126
# 3               27341            27226            27159            26973
# 4               22861            22733            22642            22512
# ...               ...              ...              ...              ...
# 3188            43593            44041            45104            45162
# 3189            21297            21482            21697            22347
# 3190            21102            20912            20989            21022
# 3191             8545             8469             8443             8443
# 3192             7181             7114             7065             7160
#
#       POPESTIMATE2014        AVG
# 0             4846411  4815860.4
# ...

# %%
result_df = df.drop(frames,axis=1)

# %%
'POPESTIMATE2010' in result_df.columns
# Out:
# False

# %%
df = pd.DataFrame(
    ['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
    index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'],
    columns = ['Grades']
)
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
my_categories= pd.CategoricalDtype(categories=['D','D+','C-','C','C+','B-','B','B+','A-', 'A','A+'],ordered=True)

# %%
grades = df['Grades'].astype(my_categories)

# %%
grades
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
result = grades[(grades>'B') & (grades<'A')]
result
# Out:
# excellent    A-
# good         B+
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
import pandas as pd

# %%
(pd.Timestamp('11/29/2019') + pd.offsets.MonthEnd()).weekday()
# Out:
# 5

# %%
df = pd.DataFrame(
    ['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
    index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'],
    columns = ['Grades']
)
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                         "bar", "bar", "bar", "bar"],
                   "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                   "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})

# %%
filling_mean =lambda g: g.fillna(g.mean())
df
# Out:
#      A  D  E
# 0  foo  1  2
# 1  foo  2  4
# 2  foo  2  5
# 3  foo  3  5
# 4  foo  3  6
# 5  bar  4  6
# 6  bar  5  8
# 7  bar  6  9
# 8  bar  7  9

# %%
df.groupby('A').apply(filling_mean)
# Out:
#                    A   D   E
# A
# bar     barbarbarbar  22  32
# foo  foofoofoofoofoo  11  22

# %%
df.groupby('A')

# %%
df = pd.DataFrame({ 'A':['foo','foo','bar','bar'],
                    'B':[np.nan, 2, np.nan, 0],
                    'C':[3, 4, np.nan, 1],
                    'D':[np.nan, np.nan, np.nan, 5],
                    'E':[np.nan, 3, np.nan, 4],
                  })

# %%
df
# Out:
#      A    B    C    D    E
# 0  foo  NaN  3.0  NaN  NaN
# 1  foo  2.0  4.0  NaN  3.0
# 2  bar  NaN  NaN  NaN  NaN
# 3  bar  0.0  1.0  5.0  4.0

# %%
filling_mean = lambda g: g.fillna(g.sum())

# %%
df.groupby('A').head()
# Out:
#      A    B    C    D    E
# 0  foo  NaN  3.0  NaN  NaN
# 1  foo  2.0  4.0  NaN  3.0
# 2  bar  NaN  NaN  NaN  NaN
# 3  bar  0.0  1.0  5.0  4.0

# %%
type(df.groupby('A').apply(filling_mean))
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('A').apply(filling_mean)
# Out:
#          A    B    C    D    E
# A
# bar 2  bar  0.0  1.0  5.0  4.0
#     3  bar  0.0  1.0  5.0  4.0
# foo 0  foo  2.0  3.0  0.0  3.0
#     1  foo  2.0  4.0  0.0  3.0

# %%
type(df.groupby('A').transform(filling_mean))
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'packaging': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
})

# %%
df
# Out:
#      brand packaging  rating
# 0  Yum Yum       cup     4.0
# 1  Yum Yum       cup     4.0
# 2  Indomie       cup     3.5
# 3  Indomie      pack    15.0
# 4  Indomie      pack     5.0

# %%
df[df.duplicated(subset=['rating'])]
# Out:
#      brand packaging  rating
# 1  Yum Yum       cup     4.0

# %%
df.duplicated(subset=['rating'])
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
import pandas as pd
(pd.Timestamp('11/29/2019') + pd.offsets.MonthEnd()).weekday()
# Out:
# 5
